# %% [markdown]
# # Bokeh
#
# Bokeh es similar a Plotly en cuanto a que depende de una librería Javascript externa.
#
# Facilita la creación de Visualizaciones Interactivas.
#
# http://bokeh.pydata.org/
#
# La guia del usuario es muy completa y recomendable.
#
#
# ### Integración con Notebooks o Generación de HTML
#
# Si se utiliza output_file o output_notebook, se puede exportar la visualización en el Notebook o bien a un archivo independiente.

# %%
from bokeh.plotting import figure, output_file, output_notebook, show

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
#output_file("log_lines.html")
output_notebook()

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="792ccd41-0f92-4567-99f2-7b3b64c10062"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("792ccd41-0f92-4567-99f2-7b3b64c10062");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '792ccd41-0f92-4567-99f2-7b3b64c10062' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"db774a5e-327e-443e-a4c7-88ae03a750ca":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9178346-2736-4643-82fd-4a1dffb7e9bc","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[0.010000000000000002,0.25,1.0,2.25,4.0,6.25,9.0]}},"id":"431b51ea-0b0a-407e-875e-95b9ad1e83de","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"302f0e21-4698-44e4-839b-b85bd42f7723","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5c50bb01-8686-4ae3-a8b9-894991684ea8","type":"PanTool"},{"id":"03e8adac-c869-4e97-92c3-d84f583c13cc","type":"BoxZoomTool"},{"id":"70b04906-2887-4eeb-b49a-318f592c2d01","type":"ResetTool"},{"id":"a2a00672-3a21-47da-a20d-e64a41de2876","type":"SaveTool"}]},"id":"23b70025-1500-4191-93af-52ef9f95f2e6","type":"Toolbar"},{"attributes":{},"id":"88c00da9-e029-42de-891b-b28ad9896547","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"8e25327b-d12f-4440-a0ae-11f98e889de2","type":"Line"},{"attributes":{"data_source":{"id":"25387302-ff57-4a4f-9174-20a7de94ec11","type":"ColumnDataSource"},"glyph":{"id":"ed7cd378-a87b-4b63-bf92-96417e5b9802","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1ef89ef5-7fb1-46f7-8927-6176b90669fb","type":"Circle"},"selection_glyph":null},"id":"5ad2055f-1fa6-45c1-830b-1c5398e868f7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"431b51ea-0b0a-407e-875e-95b9ad1e83de","type":"ColumnDataSource"},"glyph":{"id":"c9178346-2736-4643-82fd-4a1dffb7e9bc","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8e25327b-d12f-4440-a0ae-11f98e889de2","type":"Line"},"selection_glyph":null},"id":"e2cb2680-9d7b-4837-bd89-2ed7e3269944","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"ec236235-d61f-4bb4-bc19-b31dcbb180f2","subtype":"Figure","type":"Plot"},"ticker":{"id":"5cd27bdf-8d23-4b15-a53d-426cf4e28a51","type":"LogTicker"}},"id":"666d10eb-6bf6-4c66-8f86-39cb914e6f47","type":"Grid"},{"attributes":{"num_minor_ticks":10},"id":"5cd27bdf-8d23-4b15-a53d-426cf4e28a51","type":"LogTicker"},{"attributes":{"legends":[["y=x",[{"id":"05c37d82-edd2-44df-90e9-498070a65603","type":"GlyphRenderer"},{"id":"5ad2055f-1fa6-45c1-830b-1c5398e868f7","type":"GlyphRenderer"}]],["y=x^2",[{"id":"e2cb2680-9d7b-4837-bd89-2ed7e3269944","type":"GlyphRenderer"}]],["y=10^x",[{"id":"cf6e9235-022d-4c6e-ac2e-be7803c08d0b","type":"GlyphRenderer"},{"id":"f2c155fa-862b-413f-addc-e3562773df3b","type":"GlyphRenderer"}]],["y=10^x^2",[{"id":"5e6569ee-e4fd-49a4-b297-b6f65a992704","type":"GlyphRenderer"}]]],"plot":{"id":"ec236235-d61f-4bb4-bc19-b31dcbb180f2","subtype":"Figure","type":"Plot"}},"id":"4b90f8bc-ccd9-4410-96d4-e2c1e4c23b1e","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"f0a89dac-a0f8-47ea-8c7b-63b4e923d596","type":"Circle"},{"attributes":{"plot":null,"text":"log axis example"},"id":"3fea19ef-b18e-488d-8250-dfa306f67446","type":"Title"},{"attributes":{"data_source":{"id":"2c394280-0087-4ab4-8042-379fcc9d7f44","type":"ColumnDataSource"},"glyph":{"id":"5eec9153-2f1d-45a8-ad85-fcde52b592eb","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"cf51712f-3013-41dd-b3d0-ae092f03c615","type":"Line"},"selection_glyph":null},"id":"5e6569ee-e4fd-49a4-b297-b6f65a992704","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"38a7ba23-bbe5-4798-95c7-caf5ac8aae07","type":"ColumnDataSource"},"glyph":{"id":"b2185912-33b4-4344-b34b-48bc30fd17a1","type":"Line"},"hover_glyph":null,"nonsel ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# ### Descarga de datos de muestra
#
# Bokeh tiene un set de datos de muestra que pueden descargarse con el siguiente comando:

# %%
import bokeh.sampledata
bokeh.sampledata.download()
# Out:
# Creating /Users/tozanni/.bokeh directory
# Creating /Users/tozanni/.bokeh/data directory
# Using data directory: /Users/tozanni/.bokeh/data
# Downloading: CGM.csv (1589982 bytes)
#    1589982 [100.00%]
# Downloading: US_Counties.zip (3182088 bytes)
#    3182088 [100.00%]
# Unpacking: US_Counties.csv
# Downloading: us_cities.json (713565 bytes)
#     713565 [100.00%]
# Downloading: unemployment09.csv (253301 bytes)
#     253301 [100.00%]
# Downloading: AAPL.csv (166698 bytes)
#     166698 [100.00%]
# Downloading: FB.csv (9706 bytes)
#       9706 [100.00%]
# Downloading: GOOG.csv (113894 bytes)
#     113894 [100.00%]
# Downloading: IBM.csv (165625 bytes)
#     165625 [100.00%]
# Downloading: MSFT.csv (161614 bytes)
#     161614 [100.00%]
# Downloading: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.zip (5148539 bytes)
#    5148539 [100.00%]
# Unpacking: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.csv
# Downloading: gapminder_fertility.csv (64346 bytes)
#      64346 [100.00%]
# Downloading: gapminder_population.csv (94509 bytes)
#      94509 [100.00%]
# Downloading: gapminder_life_expectancy.csv (73243 bytes)
#      73243 [100.00%]
# Downloading: gapminder_regions.csv (7781 bytes)
#       7781 [100.00%]
# Downloading: world_cities.zip (646858 bytes)
#     646858 [100.00%]
# Unpacking: world_cities.csv
# Downloading: airports.json (6373 bytes)
#       6373 [100.00%]
# Downloading: movies.db.zip (5067833 bytes)
#    5067833 [100.00%]
# Unpacking: movies.db

# %% [markdown]
# ### Generación de charts de alto nivel e integración con Pandas
#
# http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html

# %%
from bokeh.charts import Histogram, output_file, show
from bokeh.sampledata.autompg import autompg as df

p = Histogram(df, values='hp', color='cyl',
              title="HP Distribution (color grouped by CYL)",
              legend='top_right')

output_notebook()
#output_file("histogram_color.html")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c5581f9-fffa-4bae-b07f-951d63982eda">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="4b6fa78f-3222-4f78-94b5-b728fa55e5c5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b6fa78f-3222-4f78-94b5-b728fa55e5c5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b6fa78f-3222-4f78-94b5-b728fa55e5c5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"933e126c-4327-4fea-a724-a9aeeded1ce8":{"roots":{"references":[{"attributes":{},"id":"0c8eb22b-d559-428d-93d2-164c6976e6c8","type":"ToolEvents"},{"attributes":{"data_source":{"id":"ef7a3741-30bc-4364-87f2-11aa8312a755","type":"ColumnDataSource"},"glyph":{"id":"633ced38-9780-4f59-9b03-6958df136ee0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4990b50f-c62c-452d-be30-c609057dc3fa","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3a7215f6-08cc-4ffe-b68a-54bc35e4f3a1","type":"ColumnDataSource"},"glyph":{"id":"ee14a7a7-67ba-43dd-a0ad-bd961484e9a9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"83567367-7072-4193-baec-72140034fe14","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["[46.0, 52.3]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[10.0],"label":["[46.0, 52.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.272727272727273],"x":["49.15"],"y":[5.0]}},"id":"dda43643-5125-4ad6-95d8-61398ee85b19","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"21bf9942-00ca-45f5-96ca-2326564adc53","type":"Rect"},{"attributes":{"data_source":{"id":"882c51fb-14d9-4d7a-9e98-47faf2b5f9fe","type":"ColumnDataSource"},"glyph":{"id":"4e064da1-6197-4093-bb44-d41591ab1ab8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"52c7ae39-e809-4ec0-8312-bd78b5540b48","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b5f76db-2ad4-4b53-b837-75d05a9f7760","type":"Rect"},{"attributes":{"data_source":{"id":"2f821d1a-28c9-4d35-b7c8-3fc8f49b57ef","type":"ColumnDataSource"},"glyph":{"id":"fddc54e8-ac74-4219-a361-2d6f742fc1c1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ca4dcf56-05c8-444a-9428-39d48ae0df33","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(108.7, 115.0]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[7.0],"label":["(108.7, 115.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.2727272727272805],"x":["111.85"],"y":[3.5]}},"id":"d7b8f8a1-e21c-4484-aaf1-3fa0ab455bbe","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05188330-9c80-4b17-b918-5c0e2643abbf","type":"Rect"},{"attributes":{"data_source":{"id":"c4329e29-39a4-472e-bedf-2e67785c02b6","type":"ColumnDataSource"},"glyph":{"id":"b9530530-0843-448c-b308-442fdf5da1c7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"56e3a992-453e-4984-bcc2-d26b82552733","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(58.5, 64.8]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[12.0],"label":["(58.5, 64.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.272727272727266],"x":["61.65"],"y":[6.0]}},"id":"25aa127f-73b0-459e-9e3f-696b38f43e16","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"5076c535-70e6-4c96-bb22-bb7535e040e8","type":"BoxAnnotation"},"plot":{"id":"de853fc6-0cfc-4a25-8d51-14345f58b6ef","subtype" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[17]</strong>&gt;</code></p>

# %% [markdown]
# ### Ejecutando aplicaciones interactivas
#
# El siguiente ejemplo hay que copiarlo y pegarlo a myapp.py

# %%
# myapp.py

import numpy as np

from bokeh.layouts import column
from bokeh.models import Button
from bokeh.palettes import RdYlBu3
from bokeh.plotting import figure, curdoc

# create a plot and style its properties
p = figure(x_range=(0, 100), y_range=(0, 100), toolbar_location=None)
p.border_fill_color = 'black'
p.background_fill_color = 'black'
p.outline_line_color = None
p.grid.grid_line_color = None

# add a text renderer to out plot (no data yet)
r = p.text(x=[], y=[], text=[], text_color=[], text_font_size="20pt",
           text_baseline="middle", text_align="center")

i = 0

ds = r.data_source

# create a callback that will add a number in a random location
def callback():
    global i
    ds.data['x'].append(np.random.random()*70 + 15)
    ds.data['y'].append(np.random.random()*70 + 15)
    ds.data['text_color'].append(RdYlBu3[i%3])
    ds.data['text'].append(str(i))
    ds.trigger('data', ds.data, ds.data)
    i = i + 1

# add a button widget and configure with the call back
button = Button(label="Press Me")
button.on_click(callback)

# put the button and plot in a layout and add to the document
curdoc().add_root(column(button, p))

# %% [markdown]
# Posteriormente correrlo con:
#
# bokeh serve --show myapp.py

# %% [markdown]
# ### Actualizando los charts con un thread de Python
#
# Copiar el siguiente codigo en un programa threads.py y ejecutar con bokeh serve --show threads.py

# %%
from functools import partial
import time

from concurrent.futures import ThreadPoolExecutor
from tornado import gen

from bokeh.document import without_document_lock
from bokeh.models import ColumnDataSource
from bokeh.plotting import curdoc, figure

source = ColumnDataSource(data=dict(x=[0], y=[0], color=["blue"]))
i = 0
doc = curdoc()
executor = ThreadPoolExecutor(max_workers=2)

def blocking_task(i):
    time.sleep(1)
    return i

# the unlocked callback uses this locked callback to safely update
@gen.coroutine
def locked_update(i):
    source.stream(dict(x=[source.data['x'][-1]+1], y=[i], color=["blue"]))

# this unclocked callback will not prevent other session callbacks from
# executing while it is in flight
@gen.coroutine
@without_document_lock
def unlocked_task():
    global i
    i += 1
    res = yield executor.submit(blocking_task, i)
    doc.add_next_tick_callback(partial(locked_update, i=res))

@gen.coroutine
def update():
    source.stream(dict(x=[source.data['x'][-1]+1], y=[i], color=["red"]))

p = figure(x_range=[0, 100], y_range=[0,20])
l = p.circle(x='x', y='y', color='color', source=source)

doc.add_periodic_callback(unlocked_task, 1000)
doc.add_periodic_callback(update, 200)
doc.add_root(p)

# %% [markdown]
# ## Ejemplos de aplicaciones completas
#
# Lo mas recomendable es clonar el repo y correr algunas aplicaciones.
#
# git clone "https://github.com/bokeh/bokeh"
#
# Luego, desde el subdirectorio examples/apps, ejecutar:
#
# bokeh serve --show gapminder/
