# %% [markdown]
# # Fuentes de datos

# %% [markdown]
# Crear un nuevo env de Conda:
#
#
# `conda create -n fuentes_de_datos python=3.5 pandas openpyxl xlrd beautifulsoup4 scrapy lxml html5lib`

# %% [markdown]
# ## Pandas y DataFrames http://pandas.pydata.org/
#
#
#
# <a href="http://pandas.pydata.org/"><img src="img/pandas-web.png" style="float:center;height:400px"/></a>

# %% [markdown]
# pandas:
#
# - Librería Open Source para análisis de datos
# - Python
# - Equivalente a data.frame y Dplyr de R-lang
#
# pandas is an open source Python library for data analysis. Python has always been great for prepping and munging data, but it's never been great for analysis - you'd usually end up using R or loading it into a database and using SQL (or worse, Excel). pandas makes Python great for analysis.

# %% [markdown]
# Estructuras de datos:
#     - Series
#     - DataFrames

# %% [markdown]
# ## `import pandas as pd`

# %%
import pandas as pd

# %%
# Series
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
s
# Out:
# 0                7
# 1       Heisenberg
# 2             3.14
# 3      -1789710578
# 4    Happy Eating!
# dtype: object

# %%
# DataFrame
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %% [markdown]
# ## Pandas IO Tools
#
# - read_csv  / CSV file
# - read_excel / MS Excel
# - read_hdf   / HDF5-Pytables
# - read_sql / SQL Query
# - read_json / JSON file-JSON dump
# - read_msgpack (experimental) / Binary serialization
# - read_html / HTML Tables
# - read_gbq (experimental)  / Google BigQuery
# - read_stata   / STATA
# - read_sas   / SAS
# - read_clipboard
# - read_pickle  / pickle — Python object serialization
#
#
# - to_csv
# - to_excel
# - to_hdf
# - to_sql
# - to_json
# - to_msgpack (experimental)
# - to_html
# - to_gbq (experimental)
# - to_stata
# - to_clipboard
# - to_pickle

# %% [markdown]
# **Working with Excel Files in Python - http://www.python-excel.org/**
#  - `openpyxl`:
#      - A Python library to read/write Excel 2010 xlsx/xlsm files
#      - https://openpyxl.readthedocs.io/en/default/
#  - `xldr`
#      - Library for developers to extract data from Microsoft Excel (tm) spreadsheet files
#      - http://xlrd.readthedocs.io/en/latest/

# %%
# reading from CSV
csv_dataframe = pd.read_csv('data/FL_insurance_sample.csv')

# %%
# reading from CSV
csv_dataframe_500000_rows = pd.read_csv('data/Spreadsheet-500000-rows.csv', encoding = "ISO-8859-1")

# %%
len(csv_dataframe_500000_rows)
# Out:
# 499999

# %%
csv_dataframe_500000_rows.head()
# Out:
#     Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre    3  \
# 0  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French  293
# 1   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French  293
# 2                                               R380      Clay Rozendal  483
# 3                           Holmes HEPA Air Purifier     Carlos Soltero  515
# 4  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero  515
#
#    -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37

# %%
# Reading data from Excel
pd.read_excel('data/FL_insurance_sample.xlsx', 'Sheet1', index_col=None, na_values=['NA'])

# %%
# Reading JSON
pd.read_json('https://api.github.com/repos/pydata/pandas/issues?per_page=5')
# Out:
#    assignee                                               body closed_at  \
# 0       NaN  closes #13448\r\n\r\nThis built locally (on Wi...       NaT
# 1       NaN  The feature I'd like to suggest/request is pre...       NaT
# 2       NaN  I ran into the following exception when using ...       NaT
# 3       NaN  Pandas `Resampler.nunique` appears to be putti...       NaT
# 4       NaN  df = pd.DataFrame({'A' : [1, 1, 3, 4], 'B': [7...       NaT
#
#    comments                                       comments_url  \
# 0         0  https://api.github.com/repos/pydata/pandas/iss...
# 1         1  https://api.github.com/repos/pydata/pandas/iss...
# 2         1  https://api.github.com/repos/pydata/pandas/iss...
# 3         3  https://api.github.com/repos/pydata/pandas/iss...
# 4         2  https://api.github.com/repos/pydata/pandas/iss...
#
#            created_at                                         events_url  \
# 0 2016-06-15 22:39:24  https://api.github.com/repos/pydata/pandas/iss...
# 1 2016-06-15 21:15:06  https://api.github.com/repos/pydata/pandas/iss...
# 2 2016-06-15 20:38:26  https://api.github.com/repos/pydata/pandas/iss...
# 3 2016-06-15 19:05:16  https://api.github.com/repos/pydata/pandas/iss...
# 4 2016-06-15 15:55:35  https://api.github.com/repos/pydata/pandas/iss...
#
#                                         html_url         id  \
# 0    https://github.com/pydata/pandas/pull/13456  160540232
# 1  https://github.com/pydata/pandas/issues/13455  160525643
# 2  https://github.com/pydata/pandas/issues/13454  160518194
# 3  https://github.com/pydata/pandas/issues/13453  160499155
# 4  https://github.com/pydata/pandas/issues/13452  160458616
#
#                                               labels  \
# 0                                                 []
# 1  [{'url': 'https://api.github.com/repos/pydata/...
# 2  [{'url': 'https://api.github.com/repos/pydata/...
# 3  [{'url': 'https://api.github.com/repos/pydata/...
# 4  [{'url': 'https://api.github.com/repos/pydata/...
#
#                          ...                         locked milestone  number  \
# 0                        ...                          False       NaN   13456
# 1                        ...                          False       NaN   13455
# 2                        ...                          False       NaN   13454
# 3                        ...                          False       NaN   13453
# 4                        ...                          False       NaN   13452
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pydata/p...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                repository_url state  \
# 0  https://api.github.com/repos/pydata/pandas  open
# 1  https://api.github.com/repos/pydata/pandas  open
# 2  https://api.github.com/repos/pydata/pandas  open
# 3  https://api.github.com/repos/pydata/pandas  open
# 4  https://api.github.com/repos/pydata/pandas  open
#
#                                                title          updated_at  \
# 0                              BLD: use inline macro 2016-06-15 22:39:24
# 1         Feature Request: groupby retaining indexes 2016-06-15 22:24:30
# 2  Exception when calling read_gbq : No module na... 2016-06-15 22:23:06
# 3     Resampler.nunique counting data more than once 2016-06-15 22:22:29
# 4                 index disappears on groupby.rank() 2016-06-15 18:41:48
#
#                                                  url  \
# 0  https://api.github.com/repos/pydata/pandas/iss...
# 1  https://api.github.com/repos/pydata/pandas/iss...
# 2  https://api.github.com/repos/pydata/pandas/iss...
# 3  https://api.github.com/repos/pydata/pandas/iss...
# 4  https://api.github.com/repos/pydata/pandas/iss...
#
#                                                 user
# 0  {'gravatar_id': '', 'gists_url': 'https://api....
# 1  {'gravatar_id': '', 'gists_url': 'https://api....
# 2  {'gravatar_id': '', 'gists_url': 'https://api....
# 3  {'gravatar_id': '', 'gists_url': 'https://api....
# 4  {'gravatar_id': '', 'gists_url': 'https://api....
#
# [5 rows x 21 columns]

# %%
# Reading HDF5
import numpy as np
import h5py

pd.read_hdf('foo.h5','df')

# %%
# Read from a SQL Query


# Set up connection parameters
db_connection = psycopg2.connect(host="",user="", password="", dbname="")

# Connect to the database server
db_cursor = db_connection.cursor()

# Specify a query with SQL
sql_query = "SELECT * from XX"

# Execute SQL query and save it to a DataFrame
sql_dataframe = pandas.read_sql_query(sql_query, db_connection)

db_connection.close()

# %%
# Read from a SQL Query
import sqlite3

# Set up connection parameters
db_connection =  sqlite3.connect('data/veekun-pokedex.sqlite')

pokemon = pd.read_sql_query('SELECT * FROM  pokemon WHERE pokemon.height > 4 and pokemon.weight > 5', db_connection)

#pokemon = pd.read_sql_query('SELECT * FROM  pokemon', db_connection)

# %%
len(pokemon)
# Out:
# 784

# %% [markdown]
# # Web Scrapping con PANDAS

# %%
import pandas as pd  # Cargar modulo


# Asignar el resultado del metodo read_html a densidad_paises
# Parametro header=0 para establecer el header de la tabla
# Consultar: http://pandas.pydata.org/pandas-docs/stable/gotchas.html#html-gotchas
densidad_paises = pd.read_html('https://simple.wikipedia.org/wiki/List_of_countries_by_population_density', header=0)

# Observar los primeros 10 registros
densidad_paises[0][:10]
# Out:
#   Rank  Unnamed: 1 Country/or dependent territory Population  \
# 0    1         NaN                  Macau (China)     541200
# 1    2         NaN                         Monaco      33000
# 2    3         NaN                      Singapore    5076700
# 3    4         NaN              Hong Kong (China)    7264100
# 4    5         NaN                 Gibraltar (UK)      31000
# 5    6         NaN                   Vatican City        826
# 6    7         NaN                        Bahrain    1234596
# 7    8         NaN                          Malta     417617
# 8    9         NaN                   Bermuda (UK)      65000
# 9   10         NaN     Sint Maarten (Netherlands)      37429
#
#     Date last updated Area (km2) Area (mi2) Density (/km2) Density (/mi2)  \
# 0  September 30, 2009       29.2       11.3          18534          48003
# 1                2009       1.95       0.75          16923          43830
# 2                2010      710.2      274.2           7148          18513
# 3                2014       1104        426           6349          16444
# 4                2009        6.8        2.6           4559          11808
# 5                2009       0.44       0.17           1877           4861
# 6                2010        750        290           1646           4263
# 7     January 1, 2011        316        122           1322           3424
# 8                2009         53         20           1226           3175
# 9     January 1, 2010         34         13           1101           2852
#
#                Notes
# 0                [1]
# 1             [2][3]
# 2                [4]
# 3                [5]
# 4                [2]
# 5             [2][6]
# 6               [10]
# 7  Eurostat estimate
# 8                [2]
# 9                [2]

# %%
# Que tipo de objeto tenemos?
type(densidad_paises)
# Out:
# list

# %%
# Como lo convertimos en un dataframe?

densidad_paises_dataframe = pd.DataFrame(densidad_paises[0])

# %%
# Que tipo de objeto tenemos?
type(densidad_paises_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
densidad_paises_dataframe.head()
# Out:
#   Rank  Unnamed: 1 Country/or dependent territory Population  \
# 0    1         NaN                  Macau (China)     541200
# 1    2         NaN                         Monaco      33000
# 2    3         NaN                      Singapore    5076700
# 3    4         NaN              Hong Kong (China)    7264100
# 4    5         NaN                 Gibraltar (UK)      31000
#
#     Date last updated Area (km2) Area (mi2) Density (/km2) Density (/mi2)  \
# 0  September 30, 2009       29.2       11.3          18534          48003
# 1                2009       1.95       0.75          16923          43830
# 2                2010      710.2      274.2           7148          18513
# 3                2014       1104        426           6349          16444
# 4                2009        6.8        2.6           4559          11808
#
#     Notes
# 0     [1]
# 1  [2][3]
# 2     [4]
# 3     [5]
# 4     [2]

# %%
densidad_paises_dataframe.keys()
# Out:
# Index(['Rank', 'Unnamed: 1', 'Country/or dependent territory', 'Population',
#        'Date last updated', 'Area (km2)', 'Area (mi2)', 'Density (/km2)',
#        'Density (/mi2)', 'Notes'],
#       dtype='object')

# %%
densidad_paises_clean = densidad_paises_dataframe.copy()

# %%
# http://pandas.pydata.org/pandas-docs/stable/dsintro.html#column-selection-addition-deletion
densidad_paises_clean.pop('Unnamed: 1')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 212   NaN
# 213   NaN
# 214   NaN
# 215   NaN
# 216   NaN
# 217   NaN
# 218   NaN
# 219   NaN
# 220   NaN
# 221   NaN
# 222   NaN
# 223   NaN
# 224   NaN
# 225   NaN
# 226   NaN
# 227   NaN
# 228   NaN
# 229   NaN
# 230   NaN
# 231   NaN
# 232   NaN
# 233   NaN
# 234   NaN
# 235   NaN
# 236   NaN
# 237   NaN
# 238   NaN
# 239   NaN
# 240   NaN
# 241   NaN
# Name: Unnamed: 1, dtype: float64

# %%
# Verificar
densidad_paises_clean
# Out:
#      Rank      Country/or dependent territory  Population   Date last updated  \
# 0       1                       Macau (China)      541200  September 30, 2009
# 1       2                              Monaco       33000                2009
# 2       3                           Singapore     5076700                2010
# 3       4                   Hong Kong (China)     7264100                2014
# 4       5                      Gibraltar (UK)       31000                2009
# 5       6                        Vatican City         826                2009
# 6       7                             Bahrain     1234596                2010
# 7       8                               Malta      417617     January 1, 2011
# 8       9                        Bermuda (UK)       65000                2009
# 9      10          Sint Maarten (Netherlands)       37429     January 1, 2010
# 10     11                            Maldives      309000                2009
# 11     12                          Bangladesh   142319000                2011
# 12     13                         Jersey (UK)       97857                 NaN
# 13     14                       Guernsey (UK)       65726                 NaN
# 14     15               Saint-Martin (France)       35263     January 1, 2009
# 15     16          Republic of China (Taiwan)    23069345       June 30, 2009
# 16     17                           Mauritius     1288000                2009
# 17     18                            Barbados      256000                2009
# 18     19                 Aruba (Netherlands)      107000                2009
# 19     20             Palestinian territories     4100000           Dec, 2010
# 20     21                          San Marino       30800     January 1, 2008
# 21     22                    Mayotte (France)      186452     January 1, 2009
# 22     23                         South Korea    48456369                2009
# 23     24                               Nauru        9322                2009
# 24     25                    Puerto Rico (US)     3982000                2009
# 25     26               Curaçao (Netherlands)      142180     January 1, 2010
# 26     27                             Lebanon     4224000                2009
# 27     28           Saint-Barthélemy (France)        8450     January 1, 2009
# 28     29                              Tuvalu       10441                2009
# 29     30                         Netherlands    17110000       June 15, 2016
# ..    ...                                 ...         ...                 ...
# 212   213                              Norway     5193840       June 15, 2016
# 213   214                         South Sudan     8260490      April 22, 2008
# 214   215                               Niger    15290000                2009
# 215   216                        Saudi Arabia    28146658                2011
# 216   217                                Mali    14517176       April 1, 2009
# 217   218               Republic of the Congo     3998904                2009
# 218   219                        Turkmenistan     5110000                2009
# 219   220                                Oman     2845000                2009
# 220   221                             Bolivia     9879000                2009
# 221   222                                Chad    11274106           June 2009
# 222   223                              Russia   142905208       April 25,[75]
# 223   224                  Niue (New Zealand)        2000                2009
# 224   225            Central African Republic     4422000                2009
# 225   226                          Kazakhstan    17010000        July 1, 2013
# 226   227                               Gabon     1475000                2009
# 227   228                               Libya     6420000                2009
# 228   229                              Guyana      762000                2009
# 229   230                              Canada    33740000   November 23, 2010
# 230   231                            Botswana     1950000                2009
# 231   232                          Mauritania     3291000                2009
# 232   233                            Suriname      520000                2009
# 233   234                             Iceland      318452     January 1, 2011
# 234   235                           Australia    23839595        June 1, 2016
# 235   236                             Namibia     2171000                2009
# 236   237              French Guiana (France)      187056                 NaN
# 237   238    Western Sahara (status disputed)      513000                2009
# 238   239                            Mongolia     2671000                2009
# 239   240   Falkland Islands (United Kingdom)        3140                2009
# 240   241                 Greenland (Denmark)       57001                2011
# 241  Rank  Country/region of special position  Population   Date last updated
#
#      Area (km2)  Area (mi2)  Density (/km2)  Density (/mi2)  \
# 0          29.2        11.3           18534           48003
# 1          1.95        0.75           16923           43830
# 2         710.2       274.2            7148           18513
# 3          1104         426            6349           16444
# 4           6.8         2.6            4559           11808
# 5          0.44        0.17            1877            4861
# 6           750         290            1646            4263
# 7           316         122            1322            3424
# 8            53          20            1226            3175
# 9            34          13            1101            2852
# 10          298         115            1037            2686
# 11       147570       56980             964            2497
# 12          116          45             844            2186
# 13           78          30             843            2183
# 14         53.2        20.5             663            1717
# 15        35980       13890             639            1655
# 16         2040         790             631            1634
# 17          430         170             595            1541
# 18          193          75             554            1435
# 19         6020        2320             681            1764
# 20           61          24             505            1308
# 21          374         144             499            1292
# 22        99538       38432             487            1261
# 23           21         8.1             444            1150
# 24         8875        3427             449            1163
# 25          444         171             446            1155
# 26        10452        4036             404            1046
# 27           21         8.1             402            1041
# 28           26          10             402            1041
# 29        41526       16033             412            1067
# ..          ...         ...             ...             ...
# 212      385155      148709              13              34
# 213      619745      239285              13              34
# 214     1267000      489000              12              31
# 215     2149690      830000              12              31
# 216     1240192      478841              12              31
# 217      342000      132000              12              31
# 218      488100      188500              10              26
# 219      309500      119500             9.2              24
# 220     1098581      424164               9              23
# 221     1284000      496000             8.8              23
# 222    17098242     6601668             8.3              21
# 223         260         100             7.7              20
# 224      622984      240535             7.1              18
# 225     2724900     1052100             6.2              16
# 226      267668      103347             5.5              14
# 227     1759540      679360             3.6             9.3
# 228      214969       83000             3.5             9.1
# 229     9984670     3855100             3.4             8.8
# 230      581730      224610             3.4             8.8
# 231     1025520      395960             3.2             8.3
# 232      163820       63250             3.2             8.3
# 233      103000       40000             3.1             8.0
# 234     7682300     2966200             3.3             8.5
# 235      824292      318261             2.6             6.7
# 236       90000       35000             2.1             5.4
# 237      266000      103000             1.9             4.9
# 238     1564116      603909             1.7             4.4
# 239       12173        4700            0.26            0.67
# 240     2175600      840000           0.026           0.067
# 241  Area (km2)  Area (mi2)  Density (/km2)  Density (/mi2)
#
#                                   Notes
# 0                                   [1]
# 1                                [2][3]
# 2                                   [4]
# 3                                   [5]
# 4                                   [2]
# 5                                [2][6]
# 6                                  [10]
# 7                     Eurostat estimate
# 8                                   [2]
# 9                                   [2]
# 10                                  [2]
# 11                               [2][7]
# 12   [9] 2011 Census figure 97,857 [11]
# 13                                 [10]
# 14                                 [11]
# 15                                 [12]
# 16                                  [2]
# 17                                  [2]
# 18                                  [2]
# 19                                 [13]
# 20                                 [14]
# 21                             [11][15]
# 22                              [2][16]
# 23                                  [2]
# 24                                  [2]
# 25                                  [2]
# 26                                  [2]
# 27                                 [11]
# 28                                  [2]
# 29                                 [17]
# ..                                  ...
# 212                                [72]
# 213                                [67]
# 214                                 [2]
# 215                                 [2]
# 216                                [73]
# 217                                 [2]
# 218                                 [2]
# 219                                 [2]
# 220                                 [2]
# 221                                [74]
# 222                                [76]
# 223                                 [2]
# 224                                 [2]
# 225                                [77]
# 226                                 [2]
# 227                                 [2]
# 228                                 [2]
# 229                                [78]
# 230                                 [2]
# 231                                 [2]
# 232                                 [2]
# 233                  Statistics Iceland
# 234                                [79]
# 235                                 [2]
# 236                                 NaN
# 237                                 [2]
# 238                                 [2]
# 239                                 [2]
# 240                             [2][80]
# 241                               Notes
#
# [242 rows x 9 columns]

# %%
# 
densidad_paises_clean.pop('Area (mi2)')
# Out:
# 0            11.3
# 1            0.75
# 2           274.2
# 3             426
# 4             2.6
# 5            0.17
# 6             290
# 7             122
# 8              20
# 9              13
# 10            115
# 11          56980
# 12             45
# 13             30
# 14           20.5
# 15          13890
# 16            790
# 17            170
# 18             75
# 19           2320
# 20             24
# 21            144
# 22          38432
# 23            8.1
# 24           3427
# 25            171
# 26           4036
# 27            8.1
# 28             10
# 29          16033
#           ...
# 212        148709
# 213        239285
# 214        489000
# 215        830000
# 216        478841
# 217        132000
# 218        188500
# 219        119500
# 220        424164
# 221        496000
# 222       6601668
# 223           100
# 224        240535
# 225       1052100
# 226        103347
# 227        679360
# 228         83000
# 229       3855100
# 230        224610
# 231        395960
# 232         63250
# 233         40000
# 234       2966200
# 235        318261
# 236         35000
# 237        103000
# 238        603909
# 239          4700
# 240        840000
# 241    Area (mi2)
# Name: Area (mi2), dtype: object

# %%
densidad_paises_clean.pop('Density (/mi2)')
# Out:
# 0               48003
# 1               43830
# 2               18513
# 3               16444
# 4               11808
# 5                4861
# 6                4263
# 7                3424
# 8                3175
# 9                2852
# 10               2686
# 11               2497
# 12               2186
# 13               2183
# 14               1717
# 15               1655
# 16               1634
# 17               1541
# 18               1435
# 19               1764
# 20               1308
# 21               1292
# 22               1261
# 23               1150
# 24               1163
# 25               1155
# 26               1046
# 27               1041
# 28               1041
# 29               1067
#             ...
# 212                34
# 213                34
# 214                31
# 215                31
# 216                31
# 217                31
# 218                26
# 219                24
# 220                23
# 221                23
# 222                21
# 223                20
# 224                18
# 225                16
# 226                14
# 227               9.3
# 228               9.1
# 229               8.8
# 230               8.8
# 231               8.3
# 232               8.3
# 233               8.0
# 234               8.5
# 235               6.7
# 236               5.4
# 237               4.9
# 238               4.4
# 239              0.67
# 240             0.067
# 241    Density (/mi2)
# Name: Density (/mi2), dtype: object

# %%
# for cycle
column_list = []
for element in column_list:
    dataframe.pop(element)

# %%
densidad_paises_clean.head()
# Out:
#   Rank Country/or dependent territory Population   Date last updated  \
# 0    1                  Macau (China)     541200  September 30, 2009
# 1    2                         Monaco      33000                2009
# 2    3                      Singapore    5076700                2010
# 3    4              Hong Kong (China)    7264100                2014
# 4    5                 Gibraltar (UK)      31000                2009
#
#   Area (km2) Density (/km2)   Notes
# 0       29.2          18534     [1]
# 1       1.95          16923  [2][3]
# 2      710.2           7148     [4]
# 3       1104           6349     [5]
# 4        6.8           4559     [2]

# %%
del densidad_paises_clean['Notes']

# %%
densidad_paises_clean.head()
# Out:
#   Rank Country/or dependent territory Population   Date last updated  \
# 0    1                  Macau (China)     541200  September 30, 2009
# 1    2                         Monaco      33000                2009
# 2    3                      Singapore    5076700                2010
# 3    4              Hong Kong (China)    7264100                2014
# 4    5                 Gibraltar (UK)      31000                2009
#
#   Area (km2) Density (/km2)
# 0       29.2          18534
# 1       1.95          16923
# 2      710.2           7148
# 3       1104           6349
# 4        6.8           4559

# %%
densidad_paises_clean.rename(columns={'Population': 'Pop'}, inplace=True)

# %%
densidad_paises_clean.rename(columns={'Area (km2)': 'Area'}, inplace=True)

# %%
densidad_paises_clean.rename(columns={'Density (/km2)': 'Density'}, inplace=True)

# %% [markdown]
# ### Exportar
